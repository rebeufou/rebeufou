# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeufou/rebeufou/blob/main/S14_Dataframes_Snippets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
person_1 = {
    "first": "Mit",
    "last": "Patel",
    "email": "mitpatel@gmail.com"
}

# %%
person_1['email']
# Out:
# 'mitpatel@gmail.com'

# %%
df1 = pd.DataFrame(person_1, index = [0]) #tabular format

# %%
df1
# Out:
#   first   last               email
# 0   Mit  Patel  mitpatel@gmail.com

# %%
people = {
    "first": ['Mit', 'Rowland', 'Vish'],
    "second": ['Patel', 'John', 'Micel'],
    "email": ['mit@email', 'rowland@gmail.com', 'vish@wish.com']
}

# %%
df = pd.DataFrame(people) #on ajoute ", index = [0]" pour ne pas avoir les nombres à gauche, en première colonne

# %%
df
# Out:
#      first second              email
# 0      Mit  Patel          mit@email
# 1  Rowland   John  rowland@gmail.com
# 2     Vish  Micel      vish@wish.com

# %%
df['email']
# Out:
# 0            mit@email
# 1    rowland@gmail.com
# 2        vish@wish.com
# Name: email, dtype: object

# %%
df[['second','email']]
# Out:
#   second              email
# 0  Patel          mit@email
# 1   John  rowland@gmail.com
# 2  Micel      vish@wish.com

# %%
df.iloc[[0,1], 2] #iloc & loc : dans loc, dans la place des colonnes, on peut mettre le nom de la colonne
# Out:
# 0            mit@email
# 1    rowland@gmail.com
# Name: email, dtype: object

# %%
df.loc[[0,1],['second','email']]
# Out:
#   second              email
# 0  Patel          mit@email
# 1   John  rowland@gmail.com

# %%
df.set_index('email', inplace = True) #mettre la colonne email en premier

# %%
df
# Out:
#                      first second
# email
# mit@email              Mit  Patel
# rowland@gmail.com  Rowland   John
# vish@wish.com         Vish  Micel

# %%
df1 = pd.DataFrame({'month': [1, 4, 7, 10],
                    'year': [2012, 2014, 2013, 2014],
                    'sale': [55, 40, 84, 31]})

# %%
df1
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df1.set_index(['year','month'])
# Out:
#             sale
# year month
# 2012 1        55
# 2014 4        40
# 2013 7        84
# 2014 10       31

# %%
df1.set_index([pd.Index([1, 2, 3, 4]), 'year'])
# Out:
#         month  sale
#   year
# 1 2012      1    55
# 2 2014      4    40
# 3 2013      7    84
# 4 2014     10    31

# %%
filt = (df['second'] == 'Patel') | (df['first'] == 'Rowland')

# %%
df.loc[~filt, "email"]
# Out:
# 2    vish@wish.com
# Name: email, dtype: object

# %%
df.columns
# Out:
# Index(['first', 'second', 'email'], dtype='object')

# %%
df.columns = ['First_Name', 'Last_Name', 'Email']

# %%
df.columns = [x.lower() for x in df.columns] #mettre en minuscule

# %%
df
# Out:
#   first_name last_name              email
# 0        Mit     Patel          mit@email
# 1    Rowland      John  rowland@gmail.com
# 2       Vish     Micel      vish@wish.com

# %%
df.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace = True) #renomer les colonnes

# %%
df
# Out:
#      first   last              email
# 0      Mit  Patel          mit@email
# 1  Rowland   John  rowland@gmail.com
# 2     Vish  Micel      vish@wish.com

# %%
df.loc[2] = ['John', 'Smith', 'johnsmith@email.com']

# %%
df
# Out:
#      first   last                email
# 0      Mit  Patel            mit@email
# 1  Rowland   John    rowland@gmail.com
# 2     John  Smith  johnsmith@email.com

# %%
df.loc[2, ['last', 'email']] = ['Doe', 'johndoe@email.com']

# %%
df
# Out:
#      first   last              email
# 0      Mit  Patel          mit@email
# 1  Rowland   John  rowland@gmail.com
# 2     John    Doe  johndoe@email.com

# %%
df.loc[2, 'last'] = 'Smith'

# %%
filt = (df['email'] == 'johndoe@email.com')
df.loc[filt, 'last'] = 'Smith'

# %%
df
# Out:
#      first   last              email
# 0      Mit  Patel          mit@email
# 1  Rowland   John  rowland@gmail.com
# 2     John  Smith  johndoe@email.com

# %%
df['first'] = df['first'].str.lower()

# %%
df
# Out:
#      first   last              email
# 0      mit  Patel          mit@email
# 1  rowland   John  rowland@gmail.com
# 2     john  Smith  johndoe@email.com

# %%
df['fname'] = df['first'].str.upper() #créer une nouvelle colonne en maj

# %%
df
# Out:
#      first   last              email    fname
# 0      mit  Patel          mit@email      MIT
# 1  rowland   John  rowland@gmail.com  ROWLAND
# 2     john  Smith  johndoe@email.com     JOHN

# %%
df['email'].apply(len)
# Out:
# 0     9
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
  return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0            MIT@EMAIL
# 1    ROWLAND@GMAIL.COM
# 2    JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df
# Out:
#      first   last              email    fname
# 0      mit  Patel          mit@email      MIT
# 1  rowland   John  rowland@gmail.com  ROWLAND
# 2     john  Smith  johndoe@email.com     JOHN

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
df
# Out:
#      first   last              email    fname
# 0      mit  Patel          mit@email      MIT
# 1  rowland   John  rowland@gmail.com  ROWLAND
# 2     john  Smith  johndoe@email.com     JOHN

# %%
df['first'] = df['first'].map({'mit': 'Allen', 'rowland': 'Steve'}) #remplacer une valeur
df
# Out:
#   first   last              email    fname
# 0   NaN  Patel          mit@email      MIT
# 1   NaN   John  rowland@gmail.com  ROWLAND
# 2   NaN  Smith  johndoe@email.com     JOHN

# %%
df['first'] = df['first'].replace({'mit': 'Allen', 'rowland': 'Steve'}) #remplacer valeur

# %%
df
# Out:
#    first   last              email    fname
# 0  Allen  Patel          mit@email      MIT
# 1  Steve   John  rowland@gmail.com  ROWLAND
# 2   john  Smith  johndoe@email.com     JOHN

# %%
df['fullname'] = df['first'] + ' ' + df['second']

# %%
df
# Out:
#      first second              email      fullname
# 0      Mit  Patel          mit@email     Mit Patel
# 1  Rowland   John  rowland@gmail.com  Rowland John
# 2     Vish  Micel      vish@wish.com    Vish Micel

# %%
df.drop(columns=['first', 'second'], inplace = True)

# %%
df
# Out:
#                email
# 0          mit@email
# 1  rowland@gmail.com
# 2      vish@wish.com

# %%
df['fullname'].str.split(' ', expand = True) #séparer les éléments de la col fullname par rapport à l'espace
# Out:
#          0      1
# 0      Mit  Patel
# 1  Rowland   John
# 2     Vish  Micel

# %%
df[['first', 'second']] = df['fullname'].str.split(' ', expand = True)

# %%
df
# Out:
#      first second              email      fullname
# 0      Mit  Patel          mit@email     Mit Patel
# 1  Rowland   John  rowland@gmail.com  Rowland John
# 2     Vish  Micel      vish@wish.com    Vish Micel

# %%
df.append({'first': 'Tony'}, ignore_index = True)
# Out:
# <ipython-input-83-3dbf24da1360>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first': 'Tony'}, ignore_index = True)
#      first second              email      fullname
# 0      Mit  Patel          mit@email     Mit Patel
# 1  Rowland   John  rowland@gmail.com  Rowland John
# 2     Vish  Micel      vish@wish.com    Vish Micel
# 3     Tony    NaN                NaN           NaN

# %%
p2 = {
    'first' : ['Tony', 'Steve'],
    'second': ['Stark', 'Rogers'],
    'email': ['tony.stark@gmail.com', 'steve.rogers@gmail.com']
}

# %%
df2 = pd.DataFrame(p2)

# %%
df.append(df2, ignore_index = True, sort = False) #ajouter un df dans un autre df avec les mêmes clés
# Out:
# <ipython-input-100-40cf1f12835f>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2, ignore_index = True, sort = False) #ajouter un df dans un autre df avec les mêmes clés
#      first  second                   email      fullname
# 0      Mit   Patel               mit@email     Mit Patel
# 1     Vish   Micel           vish@wish.com    Vish Micel
# 2  Rowland    John       rowland@gmail.com  Rowland John
# 3     Tony   Stark    tony.stark@gmail.com           NaN
# 4    Steve  Rogers  steve.rogers@gmail.com           NaN

# %%
df.drop(index=4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-70926f9395d1> in <cell line: 1>()
# ----> 1 df.drop(index=4)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df.sort_values(by = 'second', ascending = False)#ordre alphabétique inverse
# Out:
#      first second              email      fullname
# 0      Mit  Patel          mit@email     Mit Patel
# 2     Vish  Micel      vish@wish.com    Vish Micel
# 1  Rowland   John  rowland@gmail.com  Rowland John

# %%
df.sort_values(by = ['second','first'], ascending = False)
# Out:
#      first second              email      fullname
# 0      Mit  Patel          mit@email     Mit Patel
# 2     Vish  Micel      vish@wish.com    Vish Micel
# 1  Rowland   John  rowland@gmail.com  Rowland John

# %%
df.sort_values(by = ['second','first'], ascending = [False,True], inplace = True)

# %%
df
# Out:
#      first second              email      fullname
# 0      Mit  Patel          mit@email     Mit Patel
# 2     Vish  Micel      vish@wish.com    Vish Micel
# 1  Rowland   John  rowland@gmail.com  Rowland John

# %%
df.sort_index()
# Out:
#      first second              email      fullname
# 0      Mit  Patel          mit@email     Mit Patel
# 1  Rowland   John  rowland@gmail.com  Rowland John
# 2     Vish  Micel      vish@wish.com    Vish Micel

# %%
df['second'].sort_values()
# Out:
# 1     John
# 2    Micel
# 0    Patel
# Name: second, dtype: object

# %%
drink = pd.read_csv("drinks.csv")

# %%
drink.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drink = drink.groupby("continent")

# %%
drink.head()
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 1             Albania             89              132             54
# 2             Algeria             25                0             14
# 3             Andorra            245              138            312
# 4              Angola            217               57             45
# 6           Argentina            193               25            221
# 7             Armenia             21              179             11
# 8           Australia            261               72            212
# 9             Austria            279               75            191
# 10         Azerbaijan             21               46              5
# 12            Bahrain             42               63              7
# 13         Bangladesh              0                0              0
# 18              Benin             34                4             13
# ...

# %%
drink[]
