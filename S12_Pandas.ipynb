# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeufou/rebeufou/blob/main/S12_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
pd.read_json?

# %%
df=pd.read_csv("Educational_Attainment_20231027.csv")

# %%
df.head(5)
# Out:
#         Geography Geography type  Year  Less Than High School Graduate  \
# 0        Atherton           Town  2014                            13.6
# 1           Colma           Town  2014                             6.3
# 2     Foster City           City  2014                            11.9
# 3  Portola Valley           Town  2014                            48.1
# 4    Redwood City           City  2014                            16.4
#
#    High School Graduate  Some College or Associate's Degree  \
# 0                  12.3                                 2.7
# 1                   6.4                                10.4
# 2                   9.7                                 2.0
# 3                   0.0                                 0.0
# 4                  10.6                                 6.6
#
#    Bachelor's Degree or Higher                Location 1
# 0                          3.5       (37.458611, -122.2)
# 1                          2.4  (37.678889, -122.455556)
# ...

# %%
df.columns = df.columns.str.replace(' ', '')
df.columns = df.columns.str.replace("'","")

# %%
df.GeographyType.unique()
df.LessThanHighSchoolGraduate.value_counts()

df.describe()
df.shape

# %%
df= pd.read_csv("survey_results_public.csv")

# %%
df.tail(10)
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 29382       29383  I agree                     I am a developer by profession
# 29383       29384  I agree                     I am a developer by profession
# 29384       29385  I agree  I used to be a developer by profession, but no...
# 29385       29386  I agree                     I am a developer by profession
# 29386       29387  I agree                     I am a developer by profession
# 29387       29388  I agree                     I am a developer by profession
# 29388       29389  I agree                     I am a developer by profession
# 29389       29390  I agree  I am not primarily a developer, but I write co...
# 29390       29391  I agree                     I am a developer by profession
# 29391       29392  I agree                     I am a developer by profession
#
#                       Age                                         Employment  \
# ...

# %%
df.shape
# Out:
# (29392, 84)

# %%
pd.set_option('display.max_columns', 85) #afficher toutes les colonnes (les 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['ToolsTechHaveWorkedWith']
# Out:
# 0                                                      NaN
# 1              Docker;Kubernetes;npm;Pip;Vite;Webpack;Yarn
# 2                         Cargo;Docker;Kubernetes;Make;Nix
# 3                           Homebrew;npm;Vite;Webpack;Yarn
# 4                                  Docker;npm;Webpack;Yarn
#                                ...
# 29387                   Gradle;Maven (build tool);Unity 3D
# 29388                                          npm;Webpack
# 29389    Docker;GNU GCC;Homebrew;Kubernetes;Make;Terraform
# 29390    Chocolatey;CMake;Google Test;Homebrew;npm;NuGe...
# 29391                                                  NaN
# Name: ToolsTechHaveWorkedWith, Length: 29392, dtype: object

# %%
df.loc[0:5, 'MainBranch':'RemoteWork'] #afficher une certaine partie des datas de 0 à 5 et des lignes MainB à RemoteW
# Out:
#                        MainBranch              Age  \
# 0                   None of these  18-24 years old
# 1  I am a developer by profession  25-34 years old
# 2  I am a developer by profession  45-54 years old
# 3  I am a developer by profession  25-34 years old
# 4  I am a developer by profession  25-34 years old
# 5  I am a developer by profession  35-44 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
# 5                                Employed, full-time
#
#                              RemoteWork
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.loc[9:5, 'MainBranch']
# Out:
# Series([], Name: MainBranch, dtype: object)

# %%
df.loc[4:9, 'MainBranch']
# Out:
# 4                       I am a developer by profession
# 5                       I am a developer by profession
# 6                       I am a developer by profession
# 7                       I am a developer by profession
# 8    I am not primarily a developer, but I write co...
# 9                       I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.loc[4:9, 'MainBranch':'ToolsTechHaveWorkedWith']
# Out:
#                                           MainBranch              Age  \
# 4                     I am a developer by profession  25-34 years old
# 5                     I am a developer by profession  35-44 years old
# 6                     I am a developer by profession  35-44 years old
# 7                     I am a developer by profession  25-34 years old
# 8  I am not primarily a developer, but I write co...  45-54 years old
# 9                     I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 4  Employed, full-time;Independent contractor, fr...
# 5                                Employed, full-time
# 6                                Employed, full-time
# 7                                Employed, full-time
# 8                                Employed, full-time
# 9                 Not employed, but looking for work
#
#                              RemoteWork  \
# 4                                Remote
# ...

# %%
df.loc[9:19,'LessThanHighSchoolGraduate':'BachelorGraduate']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BachelorGraduate'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
def mapGeography(x):
  if x =="City":
    return 1
  else:
    return 0

# %%
df['geography_mapped_value'] = df.Geographytype.apply(mapGeography)

# %%
df
# Out:
#                  Geography Geographytype  Year  LessThanHighSchoolGraduate  \
# 0                 Atherton          Town  2014                        13.6
# 1                    Colma          Town  2014                         6.3
# 2              Foster City          City  2014                        11.9
# 3           Portola Valley          Town  2014                        48.1
# 4             Redwood City          City  2014                        16.4
# 5                   Ladera           CDP  2014                         0.0
# 6               Moss Beach           CDP  2014                         4.8
# 7      South San Francisco          City  2014                        14.2
# 8                  Belmont          City  2014                        20.9
# 9                Daly City          City  2014                        13.4
# 10               San Mateo          City  2014                        16.1
# ...

# %%
df['Geographytype'].head(5)
# Out:
# 0    Town
# 1    Town
# 2    City
# 3    Town
# 4    City
# Name: Geographytype, dtype: object

# %%
baby_names = pd.read_csv('US_Baby_Names_right.csv')

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK   62.0
# 1       11350  11351   Madison  2004      F    AK   48.0
# 2       11351  11352    Hannah  2004      F    AK   46.0
# 3       11352  11353     Grace  2004      F    AK   44.0
# 4       11353  11354     Emily  2004      F    AK   41.0
# 5       11354  11355   Abigail  2004      F    AK   37.0
# 6       11355  11356    Olivia  2004      F    AK   33.0
# 7       11356  11357  Isabella  2004      F    AK   30.0
# 8       11357  11358    Alyssa  2004      F    AK   29.0
# 9       11358  11359    Sophia  2004      F    AK   28.0

# %%
baby_names = baby_names.drop(['Unnamed: 0','Id'], axis=1)

# %%
baby_names.Gender.value_counts()
# Out:
# F    266805
# M    215748
# Name: Gender, dtype: int64

# %%
baby_names.Name.sort_values()
# Out:
# 123846      Aadan
# 138678      Aadan
# 120728      Aadan
# 323950    Aadarsh
# 121886      Aaden
#            ...
# 396549      Zyria
# 235711      Zyria
# 244816     Zyriah
# 235986     Zyriah
# 393474     Zyriah
# Name: Name, Length: 482554, dtype: object

# %%
#del baby_names['Unnamed: 0'] #supprimer la colonne Unnamed: 0

# %%
baby_names['Gender'].value_counts()
# Out:
# F    266805
# M    215748
# Name: Gender, dtype: int64

# %%
names = baby_names.groupby("Name").sum()
# Out:
# <ipython-input-54-c27d10ebf270>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   names = baby_names.groupby("Name").sum()

# %%
names.head() #5 first values
# Out:
#            Year   Count
# Name
# Aadan      6031    18.0
# Aadarsh    2009     5.0
# Aaden    186937  1743.0
# Aadhav     2014     6.0
# Aadhya    40254   217.0

# %%
print(names.shape)
# Out:
# (14550, 2)

# %%
#from the biggest to the smallest
names.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-383223e6c2f9> in <cell line: 2>()
#       1 #from the biggest to the smallest
# ----> 2 names.unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
