# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeufou/rebeufou/blob/main/10_2_Datetime_Timeseries_PandasDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("10.1 Datetime Timeseries - ETH_1h.csv")

# %%
df['Date'] = pd.to_datetime(df['Date'], format= '%Y-%m-%d %I-%p')

# %%
df['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
#méthode 2
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df = read_csv("10.1 Datetime Timeseries - ETH_1h.csv", parse_dates=['Date'])

# %%
df['DayofWeek'] = df['Date'].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayofWeek
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date'].max()-df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt= (df['Date']>= '2020')
df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayofWeek
# 0        Friday
# ...

# %%
filt = (df['Date'] >= '2019') & (df['Date'] < '2020')

# %%
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayofWeek
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume',
#        'DayofWeek'],
#       dtype='object')

# %%
index_max_volume = df['Volume'].idxmax()
date_max_volume = df['Date'][index_max_volume] #accéder à la date du volume max

# %%
date_max_volume
# Out:
# Timestamp('2018-01-16 22:00:00')

# %%
filt = (df['Date'] >= pd.to_datetime('2019-01-01')) & (df['Date'] < pd.to_datetime('2020-10-10'))
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayofWeek
# ...

# %%
df.set_index('Date', inplace=True)
df['2019']
# Out:
# <ipython-input-26-74e0553fb79c>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2019']
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# ...

# %%
df['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayofWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
df['2020-01':'2020-02']['Close'] #with the column close
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
df['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
df['2020-01':'2020-02']['Close'].max()
# Out:
# 286.39

# %%
df['2020-01':'2020-02']['Close'].min()
# Out:
# 125.63

# %%
df['2020-01-10']['High'].max()
# Out:
# <ipython-input-32-c249ff3cfe6c>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01-10']['High'].max()
# 145.81

# %%
highs = df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayofWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
lows = df['Low'].resample('D').min()
lows['2020-01-01']
# Out:
# 128.12

# %%
lows.plot()
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data = pd.read_csv("Download Data - CRYPTOCURRENCY_US_COINDESK_BTCUSD.csv")

# %%
btc = pd.read_csv("BTC-2018min.csv")

# %%
btc = btc.drop('unix', axis=1)

# %%
btc
# Out:
#                        date   symbol      open      high       low     close  \
# 0       2018-12-31 23:59:00  BTC/USD   3689.26   3693.30   3689.26   3693.30
# 1       2018-12-31 23:58:00  BTC/USD   3689.26   3691.35   3689.26   3691.35
# 2       2018-12-31 23:57:00  BTC/USD   3688.83   3689.26   3688.83   3689.26
# 3       2018-12-31 23:56:00  BTC/USD   3687.87   3689.65   3686.92   3686.92
# 4       2018-12-31 23:55:00  BTC/USD   3688.28   3688.85   3685.00   3688.85
# ...                     ...      ...       ...       ...       ...       ...
# 525594  2018-01-01 00:05:00  BTC/USD  13826.10  13826.10  13734.45  13737.93
# 525595  2018-01-01 00:04:00  BTC/USD  13823.19  13826.75  13803.20  13803.20
# 525596  2018-01-01 00:03:00  BTC/USD  13847.51  13874.92  13823.19  13823.19
# 525597  2018-01-01 00:02:00  BTC/USD  13846.64  13890.35  13846.64  13847.51
# 525598  2018-01-01 00:01:00  BTC/USD  13841.01  13890.43  13841.01  13890.43
#
#         Volume BTC     Volume USD
# ...

# %%
single_date = pd.DataFrame({'Date': ['2023-11-10']})
print(single_date)
# Out:
#          Date
# 0  2023-11-10

# %%
btc['date'] = pd.to_datetime(btc['date'])
btc['date'] = pd.to_datetime(btc['date'], format= '%Y-%m-%d %I-%p')

# %%
btc['date'].resample('D')

# %%
btc['day'] = btc['date'].dt.day_name()
btc['numerical day'] = btc['date'].dt.day
btc = btc.sort_values(by='date', ascending = True)
btc
# Out:
#                       date   symbol      open      high       low     close  \
# 525598 2018-01-01 00:01:00  BTC/USD  13841.01  13890.43  13841.01  13890.43
# 525597 2018-01-01 00:02:00  BTC/USD  13846.64  13890.35  13846.64  13847.51
# 525596 2018-01-01 00:03:00  BTC/USD  13847.51  13874.92  13823.19  13823.19
# 525595 2018-01-01 00:04:00  BTC/USD  13823.19  13826.75  13803.20  13803.20
# 525594 2018-01-01 00:05:00  BTC/USD  13826.10  13826.10  13734.45  13737.93
# ...                    ...      ...       ...       ...       ...       ...
# 4      2018-12-31 23:55:00  BTC/USD   3688.28   3688.85   3685.00   3688.85
# 3      2018-12-31 23:56:00  BTC/USD   3687.87   3689.65   3686.92   3686.92
# 2      2018-12-31 23:57:00  BTC/USD   3688.83   3689.26   3688.83   3689.26
# 1      2018-12-31 23:58:00  BTC/USD   3689.26   3691.35   3689.26   3691.35
# 0      2018-12-31 23:59:00  BTC/USD   3689.26   3693.30   3689.26   3693.30
#
#         Volume BTC     Volume USD     day  numerical day
# ...

# %%
btc_resample = btc.resample('D', on='date').mean()
# Out:
# <ipython-input-105-df8435af57ea>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   btc_resample = btc.resample('D', on='date').mean()

# %%
btc_resample
# Out:
#                     open          high           low         close  \
# date
# 2018-01-01  13425.640771  13444.478819  13404.083822  13425.126317
# 2018-01-02  13876.355194  13898.509590  13855.027465  13879.358896
# 2018-01-03  14962.191285  14984.432583  14939.789938  14963.699340
# 2018-01-04  14816.667590  14839.287014  14793.340396  14818.780319
# 2018-01-05  15790.230722  15811.529299  15768.255285  15792.452507
# ...                  ...           ...           ...           ...
# 2018-12-27   3717.897514   3719.752285   3715.947479   3717.803833
# 2018-12-28   3700.601312   3702.732458   3698.758549   3700.835333
# 2018-12-29   3873.518549   3875.227667   3871.842590   3873.553174
# 2018-12-30   3787.820118   3789.480194   3786.359181   3788.032056
# 2018-12-31   3757.299722   3758.726167   3755.904264   3757.362417
#
#             Volume BTC     Volume USD  numerical day
# date
# 2018-01-01    5.339168   71399.676011            1.0
# ...

# %%
btc_resample.plot()
# Out:
# <Axes: xlabel='date'>

# %%
btc.resample('D').agg({'open': 'min', 'close': 'max', 'high': 'max', 'low': 'min', 'Volume BTC': 'sum', 'Volume USD': 'sum'})#en fonction des clonnes, on met des fonctions différentes sur les nombres, ex : plus petite heure d'ouverture...
# Out:
#                 open     close      high       low    Volume BTC    Volume USD
# date
# 2018-01-01  12840.00  13941.49  13941.75  12801.38   7683.062688  1.027441e+08
# 2018-01-02  12939.99  15253.00  15257.53  12910.58  16299.669303  2.291279e+08
# 2018-01-03  14549.00  15437.65  15500.00  14546.28  12275.001197  1.836658e+08
# 2018-01-04  14192.37  15394.96  15430.27  14192.37  15004.018593  2.222001e+08
# 2018-01-05  14811.00  17090.03  17200.00  14810.00  16248.914680  2.597376e+08
# ...              ...       ...       ...       ...           ...           ...
# 2018-12-27   3567.75   3835.02   3841.17   3566.00  11720.374469  4.337819e+07
# 2018-12-28   3576.88   3966.58   3970.00   3575.00  13055.718407  4.889876e+07
# 2018-12-29   3703.99   3928.50   3961.85   3702.51   6901.382332  2.668823e+07
# 2018-12-30   3691.50   3853.20   3870.00   3688.76   5736.453708  2.171977e+07
# 2018-12-31   3639.33   3832.98   3842.89   3630.00   6667.163737  2.500841e+07
#
# ...

# %%
btc.set_index('date', inplace=True)

# %%
btc
# Out:
#                       symbol      open      high       low     close  \
# date
# 2018-01-01 00:01:00  BTC/USD  13841.01  13890.43  13841.01  13890.43
# 2018-01-01 00:02:00  BTC/USD  13846.64  13890.35  13846.64  13847.51
# 2018-01-01 00:03:00  BTC/USD  13847.51  13874.92  13823.19  13823.19
# 2018-01-01 00:04:00  BTC/USD  13823.19  13826.75  13803.20  13803.20
# 2018-01-01 00:05:00  BTC/USD  13826.10  13826.10  13734.45  13737.93
# ...                      ...       ...       ...       ...       ...
# 2018-12-31 23:55:00  BTC/USD   3688.28   3688.85   3685.00   3688.85
# 2018-12-31 23:56:00  BTC/USD   3687.87   3689.65   3686.92   3686.92
# 2018-12-31 23:57:00  BTC/USD   3688.83   3689.26   3688.83   3689.26
# 2018-12-31 23:58:00  BTC/USD   3689.26   3691.35   3689.26   3691.35
# 2018-12-31 23:59:00  BTC/USD   3689.26   3693.30   3689.26   3693.30
#
#                      Volume BTC     Volume USD     day  numerical day
# date
# ...
